# %% [markdown]
# Adapted from https://keras.io/examples/lstm_text_generation/

# %%
from __future__ import print_function

import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

import sys, os, glob, json

import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
# read in all chat data in JSON format
chatData = {}
for fin in glob.glob('inputs/message_*.json'):
    with open(fin) as f:
        data = f.read()
        # for the first json file, chatData is empty -- update the dictionary
        if 'messages' not in chatData:
            chatData.update(json.loads(data))
        # after the first, 'messages' exists and we don't want to overwrite it -- so extend the dictionary
        else:
            chatData['messages'].extend(json.loads(data)['messages'])

# one key in the JSON is 'participants', which is a list of dictionaries with key 'name'
persons = [p['name'] for p in chatData['participants']]

# the other key in the JSON is 'messages', which is a list of dictionaries like: 
"""    
{"sender_name": "D",
 "timestamp_ms": 1578769599245,
 "content": "10s of thousands of messages",
 "type": "Generic"
},"""

# create a DataFrame of all messages
df = pd.DataFrame(chatData['messages'], columns = ['sender_name', 'timestamp_ms', 'content'])

# giphy or photo messages have no 'content' are dropped
df = df[df.content.notnull()]

# %%
# for each sender_name, flatten all messages into a single string
# adding periods to separate sentences
chatDataMerged = {}

for p in persons:
    messages = df[df.sender_name == p]['content'].tolist()
    # remove leading periods for one weird person...
    if p == 'C':
        for i in range(len(messages)):
            if messages[i].startswith('.'):
                messages[i] = messages[i][1:]
    chatDataMerged[p] = ". ".join(messages).lower()

# %%
# clean the data of wacky stuff...
import copy

if False:
    import string
    charactersUsedDirty = { p : sorted(list(set([c.lower() for c in chatDataMerged[p]]))) for p in persons }

    usefulCharacters = [c for c in string.ascii_lowercase] + [str(i) for i in range(10)]
    usefulCharacters.append(' ')
    usefulCharacters.append('.')

    chatDataMergedClean = copy.deepcopy(chatDataMerged)

    for p in persons:
        for c in charactersUsedDirty[p]:
            if c not in usefulCharacters:
                chatDataMergedClean[p] = chatDataMergedClean[p].replace(c, '')
        
    charactersUsed = { p : sorted(list(set([c.lower() for c in chatDataMergedClean[p]]))) for p in persons }
else:
    charactersUsed = { p : sorted(list(set([c.lower() for c in chatDataMerged[p]]))) for p in persons }
    chatDataMergedClean = copy.deepcopy(chatDataMerged)
    
char_to_n = {}
n_to_char = {}
for p in persons:
    char_to_n[p] = { c : n for n, c in enumerate(charactersUsed[p]) }
    n_to_char[p] = { n : c for n, c in enumerate(charactersUsed[p]) }

# %%
# create sub-sequences of 40 characters, and an array of the 31st characters for each
# dict key is the sender_name in question
X = { p : [] for p in persons }
Y = { p : [] for p in persons }

length = { p : len(chatDataMergedClean[p]) for p in persons }
sequenceLength = 40
step = 3

for p in persons:
    print('Sequentializing person:', p)
    for i in range(0, length[p] - sequenceLength, step):
        if (i % 1000000) == 0:
            print(i, '/', length[p] - sequenceLength)
        sequence = chatDataMergedClean[p][i:i + sequenceLength].lower()
        label = chatDataMergedClean[p][i + sequenceLength].lower()
        X[p].append(sequence)
        Y[p].append(label)
# Out:
# Sequentializing person: A
# 0 / 2307
# Sequentializing person: B
# 0 / 1119954
# Sequentializing person: C
# 0 / 4622171
# 3000000 / 4622171
# Sequentializing person: D
# 0 / 2230429
# Sequentializing person: E
# 0 / 1091223
# Sequentializing person: F
# 0 / 1956235
# Sequentializing person: G
# 0 / 241486
# Sequentializing person: H
# 0 / 980564
# Sequentializing person: I
# 0 / 3778

# %%
# from now on let's only work on one person at a time
personUsed = 'C'

print('Vectorizing person:', personUsed)
x = np.zeros((len(X[personUsed]), sequenceLength, len(charactersUsed[personUsed])), dtype=np.bool)
y = np.zeros((len(X[personUsed]), len(charactersUsed[personUsed])), dtype=np.bool)
for i, sequence in enumerate(X[personUsed]):
    if (i % 100000) == 0:
        print(i, '/', len(X[personUsed]))
    for t, char in enumerate(sequence):
        x[i, t, char_to_n[personUsed][str(char)]] = 1
    y[i, char_to_n[personUsed][Y[personUsed][i]]] = 1
# Out:
# Vectorizing person: C
# 0 / 1540724
# 100000 / 1540724
# 200000 / 1540724
# 300000 / 1540724
# 400000 / 1540724
# 500000 / 1540724
# 600000 / 1540724
# 700000 / 1540724
# 800000 / 1540724
# 900000 / 1540724
# 1000000 / 1540724
# 1100000 / 1540724
# 1200000 / 1540724
# 1300000 / 1540724
# 1400000 / 1540724
# 1500000 / 1540724

# %%
if False:
    # build the model: a single LSTM
    from keras.models import Sequential
    from keras.layers import Dense, LSTM

    model = Sequential()
    model.add(LSTM(128, input_shape=(sequenceLength, len(charactersUsed[personUsed]))))
    model.add(Dense(len(charactersUsed[personUsed]), activation='softmax'))

    from keras.optimizers import RMSprop
    optimizer = RMSprop(learning_rate=0.01)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer)
    
if True:
    from keras.models import Sequential
    from keras.layers import Dense, LSTM, Dropout
    
    model = Sequential()
    model.add(LSTM(400, input_shape=(sequenceLength, len(charactersUsed[personUsed]))))
    model.add(Dropout(0.2))
    model.add(Dense(len(charactersUsed[personUsed]), activation = 'softmax'))
    model.compile(loss = 'categorical_crossentropy', optimizer = 'adam')

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random

def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(chatDataMergedClean[personUsed]) - sequenceLength - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = chatDataMergedClean[personUsed][start_index: start_index + sequenceLength]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')

        for i in range(400):
            x_pred = np.zeros((1, sequenceLength, len(charactersUsed[personUsed])))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_to_n[personUsed][char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = n_to_char[personUsed][next_index]

            sentence = sentence[1:] + next_char

            generated += next_char
        print(generated)

# %%
from keras.callbacks import LambdaCallback
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
model.fit(x, y, batch_size=128, epochs=20, callbacks=[print_callback])
# Out:
# Epoch 1/20
# 1540724/1540724 [==============================] - 332s 216us/step - loss: 1.9884
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: " lot of gil. i'm getting pretty antsy ab"
#  lot of gil. i'm getting pretty antsy about the start and see it all and so the rest of the start on the same a find of the game that it was a some consure that is a second the same the sturn is the mass of the controns of the restrange that is a starting the strange that in the real sersed the resting of the resting of the start that i see some this is a strong the starting of the proters of the probably so i think i want to see that s
# ----- diversity: 0.5
# ----- Generating with seed: " lot of gil. i'm getting pretty antsy ab"
#  lot of gil. i'm getting pretty antsy about the some consertions. you got this it to couldn't have to a not that the still read of a mesting the may i think i sumply be a prointer the rade same of some good to the spone of the don't on the store but it was a some crosting the other on the tame famous that i have to how the ragal some thisg says that now the stire and some point of the will have not way to ser cars on the controb it man
# ----- diversity: 1.0
# ----- Generating with seed: " lot of gil. i'm getting pretty antsy ab"
#  lot of gil. i'm getting pretty antsy abohtm doenth to chare to vall part contrun to br. did morn, so havung of do the how tck wall you weirddogey farstare i cas interglating on the noth but things uff out. ho remarling now. wall that and can't see that you do that i vell for the slode heards about now works of the comus things the best non breading your. you guys don't hele most side". jpidm may i've could seit nome weth that for mean
# ----- diversity: 1.2
# ----- Generating with seed: " lot of gil. i'm getting pretty antsy ab"
#  lot of gil. i'm getting pretty antsy about  ambent i veason't it of demending. hollos't we repptames it would tle?. is sues mahe. 3 ho:. even if id you're in toad okc in furiche lossm. burghh dri tertenting there's sole it. ale a d startt 2 hegr orelens on restilr up is an on'm low muybe a dning it dagn
# -rarderm rat, and these's collingveer it was a reime you dudnano has a 7m. no even wave a buy they "in. but baponnsing withing ho was
# Epoch 2/20
# 1540724/1540724 [==============================] - 330s 214us/step - loss: 1.6398
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "ice. i pay monthly for netflix. i can ei"
# ice. i pay monthly for netflix. i can eit this is a show the stuff in the same so i can get the things. i was sure they had the show to start this into a strange but the show is the same and the station of the one of the care of the start thing we can get to be the stuff in the bad when you can get to be a second thing i was a strange thing of the thing i said the constantly is the show to the show this is the same to be to start the st
# ----- diversity: 0.5
# ----- Generating with seed: "ice. i pay monthly for netflix. i can ei"
# ice. i pay monthly for netflix. i can either and they was a creat of the talking of the start so it was a complecanter of the instraction thing. it was the rest ending. but i said the entire is pritting that what still come the same to the strange because i have to have a bit think of mown on the other of at roll. i have to start the same so what the rest went to stop the fuck this in music some game when i think the fuck is problem eno
# ----- diversity: 1.0
# ----- Generating with seed: "ice. i pay monthly for netflix. i can ei"
# ice. i pay monthly for netflix. i can eit. haha. (th. hataven to batting to separusment this possible people spend they think. but than stept 12-54930 "laa.s. b1f. oh sopthwher has trailed. it just just satiomally of "do flying. but yeah i look to the fucn and eilly because the jobled ma rule play what i still more expectation for oken-one while lew's all shippuit. which right the ause [avery stopped in off this printtfut but also given
# ----- diversity: 1.2
# ----- Generating with seed: "ice. i pay monthly for netflix. i can ei"
# ice. i pay monthly for netflix. i can either shit. goo pashing rob...0 --  h. if resora, i 4) a phenint regix
# bb theys overhik: i've going to be fleed on anything here. santy. was the boggn wiblight. https://www.youtube.com/watch?v=iurxc4qhj7i. maybe tram rumis blitt sare, it took watchat. did the aptranloyod spoll games you link. which nor?. this. i believe on shit).... speaking school now, laas. http://w¿wkyoh.com/opc-1/or-beitic-pers
# Epoch 3/20
# 1540724/1540724 [==============================] - 322s 209us/step - loss: 1.5187
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "e says he has something exciting to show"
# e says he has something exciting to show the part of the season of the show and then the fuck i was a bit that i don't want to say it was a bit to see the spell of the state that the show is a show that the real seems to be a good and the whole thing. i don't want to do the materall really and it was a second the same thing and then the thing is a good thing. i don't know what the show is a probably the state of the base and saying it w
# ----- diversity: 0.5
# ----- Generating with seed: "e says he has something exciting to show"
# e says he has something exciting to show a good seem to be a little botter than it was having the the months. i don't know it's not the start of the fuck is the distinct of being been getting that in the season a thing. i mean in what is a big book and the whele who was was flap. then the mean was the seriously seems to say you can't see the seem to the other but i don't know. but the fuck it would be a port surprised. i was too sell it
# ----- diversity: 1.0
# ----- Generating with seed: "e says he has something exciting to show"
# e says he has something exciting to show statument unangence what not perfectively. then on an a lot of right and decading the cost of gunch?. this erage just dcuptive for senier. the data. it's volon and it means this way. which, it moves bigger but i'm maring 1 had him long. i can wablen wapping and it's up haha. or all up why and i don't realize te complain donalizons, man me's day i had fag baring it. just see dain. well yeah lave a
# ----- diversity: 1.2
# ----- Generating with seed: "e says he has something exciting to show"
# e says he has something exciting to shows (big fet sorionony budds i to a dungy is twselege/ranklz. i am diethllain, where their dungs fact. https://www.youtube.com/watch?v=6hdjwoen.gn thbstuc/findom/2998mptcgct=2039439&d=3808661&mobiupqescarr. fucsting bifl to ebat simplet. i'd need a king-is siduledeeff. loot on fords just dainlism. stuff. we hoppley to seld dove. ye endedate comber. it token without a cinticenory beto wright hes, i s
# Epoch 4/20
# 1540724/1540724 [==============================] - 322s 209us/step - loss: 1.4554
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: " head and has a coin, the main story is "
#  head and has a coin, the main story is a little control in the same thing i have to see the party of the context of the same of the first thing i was thinking that they have to do the context of the same way to do that that the start was the talk of the first and the real thing i want to say that the end of the same thing i don't know what i don't know what the face is a really one of them to be a start for the context of the same shit
# ----- diversity: 0.5
# ----- Generating with seed: " head and has a coin, the main story is "
#  head and has a coin, the main story is in that one of the other point where the start takes a health and you know what i have to after the party week i'll be really people expected to be sure you could say i had a happening that we're doing some problem of a later for the same of the words and at the context of the interesting the mail and then story in a bit to what the face. i thought the destriction is some pirele. mike i don't know
# ----- diversity: 1.0
# ----- Generating with seed: " head and has a coin, the main story is "
#  head and has a coin, the main story is playing well schedal spen. he always seems to a may with this nate-in simple experience, although i need to happen to extent to make out a "scrall" a tray for where that's lelked". the boird = checks or your own mind-2 had. oh yeah cholled twitchlamerh was pacer to right ar now at it speaking of things thiie. which one just got it, the opco it for a which reconnectly saying you supporture explodio
# ----- diversity: 1.2
# ----- Generating with seed: " head and has a coin, the main story is "
#  head and has a coin, the main story is me, i asked them room. late, i'll belive it. https://avenous.com/fol. outch in blook. but there suderstools completely ~marsiory-cern-whole qualing quickle storage uproxo ng. oh hhey. pivc would be mimiid gold. if it likely quest". i hop not rat and jvingfully logattine. . oh that would be a grad storhed of a problem up. thry'll hahe with humslion and dunn that, what i keep -s can disink the same.
# Epoch 5/20
# 1540724/1540724 [==============================] - 319s 207us/step - loss: 1.4161
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "intended to have some backstory come in "
# intended to have some backstory come in the same and the track was a second thing to get a construction of the story in the same time to this shit on the same thing. the story is a script of the story of the companies of the story in the show says it was a short thing i don't know what i was a bit did they have a second of the same thing to see the same thing i was thinking about the opportunity to the stuff that was a weird shit of the
# ----- diversity: 0.5
# ----- Generating with seed: "intended to have some backstory come in "
# intended to have some backstory come in this one possible second to the massion and they have a solid professional table of the last time and i don't know what i was a pathfinder. i think it's a bit for your thing. i can decide to show up from the the companies of the dude is the end of this one with the end and it was an attack time. i also have to do any home of this post-anime?. i put it a second your line of the cop shit about it fo
# ----- diversity: 1.0
# ----- Generating with seed: "intended to have some backstory come in "
# intended to have some backstory come in every knowl and some sectsimalotist. plus it's really "in sarchange ins). this is 80% dp and building mite-waits. most lines against hall coloring me on many feel. bert/?. a roll with more upced my practicable every life. i needed to make more right to hear, ring for 15: 201-80. leedezz ake saying "oh makes some in 2 mïc scase is if the mode is, maybe i think kind of saying "but hours. xf?. i know
# ----- diversity: 1.2
# ----- Generating with seed: "intended to have some backstory come in "
# intended to have some backstory come in side ladit, i'm going. you can hummer no harry but that was your the cri1 look from ths why. my show levels in try fut. the it "get it. ficked dure and now okay, ink. jear's in gm. 1'. hend and shaberally it let it on a-celtchm, request intereet puschungely. wund the ilteriach ron/. fully creatian. sxuchevin* + parsy fo craze:. i wouldn't pracriato things 1* king get of- ravess cool progress stude
# Epoch 6/20
# 1540724/1540724 [==============================] - 320s 207us/step - loss: 1.3881
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "ffice change and +20-30 minutes commute,"
# ffice change and +20-30 minutes commute, it was a pretty company of the second thing to do with the state of the state of the second things are all and the problem in the state of the show is a strange that the fuck is the box in the show that was the first thing that have been a lot of the state of the states and it was a strength of the second stuff is that the only one is the same thing. i don't know what the point is that the stream
# ----- diversity: 0.5
# ----- Generating with seed: "ffice change and +20-30 minutes commute,"
# ffice change and +20-30 minutes commute, the strong expeciation was a short sports and because i want to call it to probably procedually annoying the creature of the point it would be doing the new show party yet. you need to start with the cose that was in offective of people and started getting as that we had to keep it and stopped it for the enemies when they can a superherder for me. but i should watch that considered when it kind o
# ----- diversity: 1.0
# ----- Generating with seed: "ffice change and +20-30 minutes commute,"
# ffice change and +20-30 minutes commute, return during his real contress. delf the streets says like. iin . deck to you lost ranch and love that. thenchit. let's get maticaline beforehape but so, what. "i have more more band down's shit. another deptromery or sovery lots with 4) and the forst open troulding material rules whoops. trump's thought i was pretty specifically now. he would des battlek coheri for me. maybe if you have to go h
# ----- diversity: 1.2
# ----- Generating with seed: "ffice change and +20-30 minutes commute,"
# ffice change and +20-30 minutes commute, 0vz oreas nuring living by states. a cestector, these two lots of cards. this asshold suddenlycop vighton to became the welp if it was hard. fai trump though. pray and talk to accest njot3 knjoston". i'llgwone ght diedon'-set-codgennation". pith hantment. you don't. because it didn't just sank for some junku". agewando large teap 201/strends". so long aboutsitateai was different. "fool. in an ign
# Epoch 7/20
# 1540724/1540724 [==============================] - 320s 208us/step - loss: 1.3667
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "e is it but i remember a better recordin"
# e is it but i remember a better recording of the show and then a second thing i want to say it was that they all see a lot of the same thing. i don't know anything to do that to do that. i was also strangely the same that should be a lot of things to do this. i was a second thing i was thinking of the show and then a base of the sentence of the story in the time i was thinking of the story in the sister of the first book or something. i
# ----- diversity: 0.5
# ----- Generating with seed: "e is it but i remember a better recordin"
# e is it but i remember a better recording of the second thing. i saw the world of the story with this shit in the thing. the store is really the first game in the country at the call of things and they were the person. i have a district of the chains of it. https://www.youtube.com/watch?v=fkh2ozhrjwa. when they all do and i would be a sentence of the movie for the show. i have no idea what we had to get them on the same of the first thi
# ----- diversity: 1.0
# ----- Generating with seed: "e is it but i remember a better recordin"
# e is it but i remember a better recording goes sthikate you've boosted. i've got bencions the. you've flip like examples uninolictisumayle?, ona. plus you supporting somewhere, and simple for just any opposite: for our pathfinder it's pretty funci. you mike every didn't, but it's that people "i liked a bit board for one videos buts to this is half so the lost word, there's always bean xby "beyond" i popended. which i just couldn't play
# ----- diversity: 1.2
# ----- Generating with seed: "e is it but i remember a better recordin"
# e is it but i remember a better recording point though.". "you never remember my, that out. i don't know which brady thtnames, one. "oh som one meet opside". but they kept to telk ouce drain. http://glothoupia.yom. e¼chat( %2 & idoainh [9 connectidaw
#
#
# 10.9/(11/tog_. @by
#  giving + unter soon). > re8ndwite potc: harr') verbuano i/faid op sets 3esato distaintion store, it's not yunf leftogue.... wow iven though i think yegence 7 spakempt
#
# Epoch 8/20
# 1540724/1540724 [==============================] - 321s 208us/step - loss: 1.3486
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "'re worried that i just might win
# you kn"
# 're worried that i just might win
# you know it was a strange thing to do that to me. i was thinking about the start of the shit out of the show to see the start and it was a strange thing and i would just really do the way to get a big thing. i was thinking about the show and the starting starting for a shitty because the show is a real station of the statistics of the lines and say that they want to be a short thing and i was thinking o
# ----- diversity: 0.5
# ----- Generating with seed: "'re worried that i just might win
# you kn"
# 're worried that i just might win
# you know it's just a strange thing. i finished the idea what i didn't really have a round sender of the second to red to do it. i don't know what i was going to start things about the one thing. i don't really want to see it was some one of these borned up to me in the shifter and i think. the target it's a server and then the internet wouldn't do this between my boss and then it was a big player that t
# ----- diversity: 1.0
# ----- Generating with seed: "'re worried that i just might win
# you kn"
# 're worried that i just might win
# you know. in myp. he jpsdess: but i didn't quit really no internet it. so it likes a per rewards in a material. for my opinion. i'm complaining to real year. if i hippering sky viztarlity. i kind of say this resoversely dope music like faster, and i need to watch the agize one day and overwander. i wouldn't assign the point tiers are much haha. but there's some granded. or amerand trap because a comment
# ----- diversity: 1.2
# ----- Generating with seed: "'re worried that i just might win
# you kn"
# 're worried that i just might win
# you know these consaut re wrong can get 98n229 anoped's. buthund a very dumf almost the liter weapons what's point...cair frama>ta, getting finish joich). my car deep paid it. nically buri. i started a different assoan this robing. impossalotes@ studene areas.
# , 190%:d5+** ye.alu. arra vide(. mf i leaked again dashtlefreps. porcodewi/oursellor/mightelle/pi overgwarts lurn once. trapter: corey stepp mile
# Epoch 9/20
# 1540724/1540724 [==============================] - 320s 207us/step - loss: 1.3336
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "out though. for flight 2 im wearing two "
# out though. for flight 2 im wearing two man and i was thinking about the second second to the part of the basement of the same thing. i was thinking about the story in the show they can see the point they were always took the content and we have the state of the same time they were the same and say it was a specific thing i want to get a bit of the status and it was a big fact that was a real state of the state thing to do the first tim
# ----- diversity: 0.5
# ----- Generating with seed: "out though. for flight 2 im wearing two "
# out though. for flight 2 im wearing two dead stuff. i don't know what a great time i have a fair tone of shit of my first business too more to get a few deal to the last thing i would put the sure. i see not to remove that some reason there's the same south it to do the whole right and shit to do a level 1 that's not a too sendor comments for the shit that they decide to make the kind of the resources of a few times. i don't know what t
# ----- diversity: 1.0
# ----- Generating with seed: "out though. for flight 2 im wearing two "
# out though. for flight 2 im wearing two drives apparently 14th undergrad. (and yeah anyone simple come mops.......they're pasting to comey was restricting. this is cured players right now, imagine but when they got up at an issue in the business guy and just use my fears, and that i'm not saying 2% all text. more. haha. now we're a bit lightful from that. what's the second time not to. if it was resetitive lower studio chesks, it has mb
# ----- diversity: 1.2
# ----- Generating with seed: "out though. for flight 2 im wearing two "
# out though. for flight 2 im wearing two people. the orp sang yot, mac grave) snow fairly infeinchens but get tree strong for linus ot, coloce, ones of reyears and the ms red cades and a on mbor privitingv-oceams or wham are slyo the realilitiat. it's going to wonder rfashings. marga. 1 time at outman god dilensionish?. if they pit me bester at a decent uhhh i just can't get read corners. none of this sheets are i want. i've never kind o
# Epoch 10/20
# 1540724/1540724 [==============================] - 320s 208us/step - loss: 1.3205
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "ton or amherst? or is it mostly cultural"
# ton or amherst? or is it mostly culturally started to be a weird shit that i have to be a problem i want to get a shitty and the rest of the start is the professional and the one thing is the back thing. i don't know what they want to get the back that i want to be a big face to a shitty back then when i want to be a shitty thing. i was thinking about the start was that they said they were the story in the state that is the same thing.
# ----- diversity: 0.5
# ----- Generating with seed: "ton or amherst? or is it mostly cultural"
# ton or amherst? or is it mostly culturally which is not a short thing for the more part of the shit that i think that they think the show is in the first force, so they say they're the land of the project i saw the content i was always wanted to be a thing change it works. i also felt we'll ever and they feel the movie at a time i have a fuck it was the business. i have this because they like the first team was a cheap on the scam that
# ----- diversity: 1.0
# ----- Generating with seed: "ton or amherst? or is it mostly cultural"
# ton or amherst? or is it mostly cultural clapping player <demand gold sent traffic but there's a link of people each where all use shoppes could watch a science baminiarage guild and good burn too, whelph. climitory you've got our good abers as a same to bagg' and no. more stories but i really have the mainfully they wait? fax but it was too back to their features out of nowhere. i'm sure they've set on the meachent. it was a leakefup i
# ----- diversity: 1.2
# ----- Generating with seed: "ton or amherst? or is it mostly cultural"
# ton or amherst? or is it mostly culturally beat, and nocha help rrest. i have, consistently trump wants to happen but maybe mk ares them an issue and differentlitics.. you could like high jekple. well it's short and decide, dooss. lyss new say we stop rolling about leboes with 8-10 ret. comments aagor i over-alchechedotes some's haday worth as an iniry wear-munerian lab 100 years ahady franking. uhh. also why a morkari peten pty is forc
# Epoch 11/20
# 1540724/1540724 [==============================] - 320s 208us/step - loss: 1.3103
#
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "an interesting point but at the same tim"
# an interesting point but at the same time i was thinking about the start and the point where they don't want to the state of the states and was the story in the same time. i was going to say they were a single point that i was thinking about the game of the problems and the point is that the problem was a strange point of the show. i don't know what i was thinking it was a defense. i think i was a single player of the game i want to be
# ----- diversity: 0.5
# ----- Generating with seed: "an interesting point but at the same tim"
# an interesting point but at the same time i kind of get this anything i don't care. i was going to do the new minute on the camera in and i feel. i think that i saw the same reason, i still have any of these times it would be a pretty much of the table. i have to kill the sister of the really. that makes me see the monster with the spell that i think i'm still everybody, i guess they don't know the good purgon things like a book and the
# ----- diversity: 1.0
# ----- Generating with seed: "an interesting point but at the same tim"
# an interesting point but at the same time, it was a rule with metam in it trying to his choice, he hadn't kicked, all many in her last times now. oh, that naved experiment now, it just does a build. i'm possible, i aggressed anyway. somehow at the same time i knew i expect with the gurlfascying, and i suppose. new happened of drundagick carrier. eutovey teleport bonk plot mad movies". with the inits or who has worried him. it's a dinver
# ----- diversity: 1.2
# ----- Generating with seed: "an interesting point but at the same tim"
# an interesting point but at the same time if question: your big average line n imagon. were thete wins pindcing rewere through, he svele lichted). my face were half: edges to repart their kids. to be right. donutifu. okay protrice?. ye...firts feeling about within at 3lm. they will be interviewing apparently. position you've predsnobagy, enough to go wack, i can't take things happen to be a bid itever 9 sense. but i'll buy the expacrati
# Epoch 12/20
# 1540724/1540724 [==============================] - 326s 212us/step - loss: 1.3004
#
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: "iant-titted woman skipping rope with a s"
# iant-titted woman skipping rope with a short thing. i still have a strange and then it was a complete and then i don't have a lot of things to see what i don't know what i have a many for the starting and show to the super-shitty and i can be a few sections and then he was a few times and then it was a problem in a second thing. i don't know if i was a big start for a second thing to the start to the point of the starting and a month an
# ----- diversity: 0.5
# ----- Generating with seed: "iant-titted woman skipping rope with a s"
# iant-titted woman skipping rope with a student really. i still know that i remember all the deal that is. i would see a weird same on the same and the money to the player substant. i was talking about the first and then the girl would be a called post of things like. i was a single real sent for your raid of short that would be the rough models. i still love this high amount of something. i still want to want to be a craft bunch of sear
# ----- diversity: 1.0
# ----- Generating with seed: "iant-titted woman skipping rope with a s"
# iant-titted woman skipping rope with a self-sustefl work. did i fail the versation and everything has anyworm expansions 2 intro strange. this isn't that yeah. that also just said next if it's in the shit that really became this engineer. bi, fpanklable. and 6 rove thing they thought you're in the same. it starts big. we started. it's terrible. hmm at also that ires, aiting use? that fucked up. he needed a weirder over one's to is a fig
# ----- diversity: 1.2
# ----- Generating with seed: "iant-titted woman skipping rope with a s"
# iant-titted woman skipping rope with a shitty other. what mechan you say he thought didn't work. 9k you're pretty sure i feel in line with god damn is if. 1 years (it's dound isree?. https://mocheboogoslindord.com/, movie's gif, each dayo because piycoin wasn't fun, jet hobizedian_ updaterine? why would've lost it's okay". basically arts yet methog zalo. looks trying fire. but my point i control you would you streade people. so chnck. i
# Epoch 13/20
# 1540724/1540724 [==============================] - 330s 214us/step - loss: 1.2974
#
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: "e answer but i kept asking how it worked"
# e answer but i kept asking how it worked a second time and the one with the state of the thing. i can't remember the last time i was thinking of the show of the point of the point was a big second time. i don't know what the first thing is the same thing. i have to see any of them and the problem is that it was a bit basically to start with the states that i was thinking of the same thing. i was thinking about this shit that i was think
# ----- diversity: 0.5
# ----- Generating with seed: "e answer but i kept asking how it worked"
# e answer but i kept asking how it worked the work-work for a right where it could be that in an office to see the same time, the song comes in the same time for a month and was sure we have to start putting and disappointing the shit you wanted to say it's interesting that the griden they want to say. this is a close to corey. https://www.youtube.com/watch?v=mkmubkq6zka. so i was still going to say it's a bunch of other resolution and g
# ----- diversity: 1.0
# ----- Generating with seed: "e answer but i kept asking how it worked"
# e answer but i kept asking how it worked away flound but doesn't are outside before a dead conspiracy, the way back copy is happening. it's a time and that's also the family. https://www.renditt.ccn/tochfinder. as a rpg mode situation intistist. someone who will still people branting on all about them. don't really think of pengles are. why i was thinking of those big classics and all speeds. sex access bloods. that the umsing. /dnitb p
# ----- diversity: 1.2
# ----- Generating with seed: "e answer but i kept asking how it worked"
# e answer but i kept asking how it worked ff a wielin other points and name doing suck and tip out cub sbit unique carden tap they'll be hard. fa opanity vilen. i have to be fyeebs for ek, though hallknote 2000 alpersia = dreamens , caf els3. spears are (1ddy?). youâre seen them for it. a two legal or u.eb cofros. runel int broken biols. bimanil effective and d. hey missing a communious talks ap all you worden?. khpchas ship nrs. i'mes
# Epoch 14/20
# 1540724/1540724 [==============================] - 335s 218us/step - loss: 1.2895
#
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: "hat. there's windup in that. and then pu"
# hat. there's windup in that. and then put on the standard and then i don't know what the fuck is the same thing. i don't know what the fuck is that they were the same thing. i have a start of the state thing that they didn't really do that. the same time i have the story and the book is the same thing. i was thinking of the show that i was thinking of the best of the story in the state of the show. i don't know if i was thinking of the
# ----- diversity: 0.5
# ----- Generating with seed: "hat. there's windup in that. and then pu"
# hat. there's windup in that. and then put it to honestly. i should have stone this action before i got it and the regular whited is a sample contact but he didn't seem to be a real straight back in the record place to be a good phone and it was a bit billion and are they both was to say this man and it was a few things to and i'm not corey's the company and there are no things to see shit on the police chat part of the content they're s
# ----- diversity: 1.0
# ----- Generating with seed: "hat. there's windup in that. and then pu"
# hat. there's windup in that. and then pushing these persons from a parthouch, so higher healbrest is fine. the party is the true time their day shit in first talent. wey are you got a character on the survivor or flash. shit to enjoy an raw spelltil 10+11. now https://www.youtube.com/matchzenmdonrpoivew4859502fm4cm2xpwjy.jps, 0/0yeatoue_cring%20srun&p=poss=8unkezwaomed=ox_yiai,ojy_wnn_acrimment. http://holbownisrd.celuber.com/starties/g
# ----- diversity: 1.2
# ----- Generating with seed: "hat. there's windup in that. and then pu"
# hat. there's windup in that. and then pulitisizing tough 12 iens 500g5. scenes ah that's an so oh ded 28680, 20 room well holy shell and following a cpariate like drive on idnon entire apcharies, just imagine yelbies despired of some (that? thinks having an omons if dis greezed him". a dude under song these powerful. 11 year old gaphil. the futuri artified things and help out i'd be c fire inter well. eopers if you invalion deferif ando
# Epoch 15/20
# 1540724/1540724 [==============================] - 336s 218us/step - loss: 1.2823
#
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: "l in general, if this problem isn't goin"
# l in general, if this problem isn't going to be a short thing. i was going to say it's a real second of the story in the state of the show. i don't know what the first company was something. i think i want to see what i don't know what the fuck is that i was thinking about the starting context of the state of the state of the starting thing i want to say "oh shit i want to start a bit at the same time. i would love to see the change the
# ----- diversity: 0.5
# ----- Generating with seed: "l in general, if this problem isn't goin"
# l in general, if this problem isn't going to be a consequence. and then we said it was a weird mean that would be a bit that the time her has age and i could have a part of the options in the access of same and then i don't know it for the city that shows a little right to fight the book and not the sound to the entire line of the tometowar with the entire card of me and the grocery show is the bill i bet that has been too much of the e
# ----- diversity: 1.0
# ----- Generating with seed: "l in general, if this problem isn't goin"
# l in general, if this problem isn't going to get that guide. driver boted holys. i could don't left hard a prom part of the leadershit. like bubger made minisuments early $6 and big windows contegt about other nown album, pretty all sake at this pilet to about the twice with dea at the airs and the thought was been about to per spell and don't it. i thought it did a bowsnst or that would be footnd and it sounds lough. you can, you know.
# ----- diversity: 1.2
# ----- Generating with seed: "l in general, if this problem isn't goin"
# l in general, if this problem isn't going moto-dute. now 2400 pyalpanious jobs like "i've been do the random zith good. let's get our shit?. puddy. konote. 3 but dice for a carry and clearly sefiero now. some hyever la?. goomy writina wreck as m1. is gropphing or what the momention. dig year, romat cover in non-the pf but, from like heim. (f_i quest. wait. what eeped their ciniory ps mentioned greachey mang. wow crasscamass. look otg. n
# Epoch 16/20
# 1540724/1540724 [==============================] - 330s 214us/step - loss: 1.2736
#
# ----- Generating text after Epoch: 15
# ----- diversity: 0.2
# ----- Generating with seed: " one occasion where i got in trouble in "
#  one occasion where i got in trouble in the state of the traits and start and it seems to be a strange time and i was thinking of some companies and the real comment of the point in the show is a bit that it was a problem in the starting and the card and the starting can also say that i was a bit bonus. i want to say that was a single of the state and the place was the only thing to do that to me. i was thinking about this but i was thi
# ----- diversity: 0.5
# ----- Generating with seed: " one occasion where i got in trouble in "
#  one occasion where i got in trouble in the big bad look. but i feel like i need to do that they. the bossess is a weird dungeon on that comment. i think i want to say that i was also there and the party decent work then he gets pretty confused. i don't know what i was really there. it's a fair thing to do that and i'm sure what you want. i said it had a fun in the puth them. but yeah i'm just fucking sucked at all to start getting out
# ----- diversity: 1.0
# ----- Generating with seed: " one occasion where i got in trouble in "
#  one occasion where i got in trouble in the young at claime and my boosts is emplone. shit was in a large chats. and i agree with pccraddary. mkettpeopogs? or something. then i'm likery armora strangers the detree is to use stauking, b$okp is drives, if you think-shitâ. couldn't play some giant ponest into bnd. and they find i add fighting draftions. i'm sure it's coult cut over to get me for writing a spell. yes, buff do my con of a
# ----- diversity: 1.2
# ----- Generating with seed: " one occasion where i got in trouble in "
#  one occasion where i got in trouble in caches swam this answer, that i've aling for $10 minutes patchers*. but af opportue 2/300 wit just eat me sfull reíusy and commult? do you obin.. month. but yeah the mocro for drunk, it's normal.. people shadow and pulls, best bestly in 2?. i'd mention trying to try extremention going through, it got that clue it moves = weeks. hee nife 18 people myself and come hero. if i know efficeles between
# Epoch 17/20
# 1540724/1540724 [==============================] - 338s 219us/step - loss: 1.2717
#
# ----- Generating text after Epoch: 16
# ----- diversity: 0.2
# ----- Generating with seed: "e. i mean for the missions you start wit"
# e. i mean for the missions you start with the states to say it was a state of the transmaiss and still started with the president of the show to the thing to do and they have to say it was a bit of the state of the states and some shit about the real thing. the story is that the show is the time. i was thinking the same time i was thinking of the hard story. i was thinking the statistical stuff is a server that was the same thing. i was
# ----- diversity: 0.5
# ----- Generating with seed: "e. i mean for the missions you start wit"
# e. i mean for the missions you start with the line and change the thing to do it to be in the thing. i was just seeing that you need to get into your case. they can also think of what they want to say "you're doing. because they should want to start at the book out of the first time and it was too late. i would start at the same time that was down to the show for the first counters. it's a protection of the situations and comes out of t
# ----- diversity: 1.0
# ----- Generating with seed: "e. i mean for the missions you start wit"
# e. i mean for the missions you start with timing threaten parkly pripcy. i went that girl shell ladges them. didn't only cast it. really nothing about hmm. i always take his aymy/lepal card. i suppose we just could kill wandstone. always feel assuling girl steps, in varchup then sanity is the up high lep to red. okay. it takes ðì. that feels as a spear for ssca lol.plu/slumbles. she is "hey damn a different private university". you ne
# ----- diversity: 1.2
# ----- Generating with seed: "e. i mean for the missions you start wit"
# e. i mean for the missions you start without hoo. tarnliee you're an album. or the games ip then each. >6th: you shouldn't indest instanted a while our name. i always wanted to get muse andain'-haller in. you know, verval. with tless0's wondy-stathed series cans. only.... and >> run. but yeah you know why thearing, how munched him to require other places. not kind of an up-and-x episode in day". and you might pan for being ething. it's
# Epoch 18/20
# 1540724/1540724 [==============================] - 352s 228us/step - loss: 1.2906
#
# ----- Generating text after Epoch: 17
# ----- diversity: 0.2
# ----- Generating with seed: " if you're talking about an upright/larg"
#  if you're talking about an upright/large thing. i have a short story and then in the back thing i should have a lot of things that i want to see it to me. i also don't know what the fuck is the start for a while. i want to say "why do you have the show of the show of the same time. the start is a strange thing to see the same time. i don't know what the fuck is a bit of the show. i was also a strange thing to see the starting thing i w
# ----- diversity: 0.5
# ----- Generating with seed: " if you're talking about an upright/larg"
#  if you're talking about an upright/large one single entire that and seems to pay to the story and i want to see the stuff and or conversant for a show and then we should have people would have been more of it constantly. i have to see what i will not say it's so interesting. i'm too annoying that it's a short mind and it doesn't need to get back to the story story. i could see why it's been the production of the last thing i want to be
# ----- diversity: 1.0
# ----- Generating with seed: " if you're talking about an upright/larg"
#  if you're talking about an upright/large without the band lills is mostly down with the dumb writing in a supplayed game, "we're going to do back kid and those vague or njn died for anything better. the comfuctive grap. it only good-houses ofttany a page was tallor spellbook. so you're not breaking things once you don't understand it. it'd be to light, but reminds me for holriagly. games jounsty it sounds used dice to start awakenisk.
# ----- diversity: 1.2
# ----- Generating with seed: " if you're talking about an upright/larg"
#  if you're talking about an upright/large on calham character evanked oka, did hines exo-wonders, but he cean i been duilds in collection or solo on my areas up see what's working on the requirion effect and "does". sweatshit respect them. haha. yeah that time. everyone would have been easy. yeah get a mistake weekend. plus, ya. were can pusped out 54d amonn that you're also seen of auboa switchable ideas. it's i just the possible year
# Epoch 19/20
# 1540724/1540724 [==============================] - 347s 226us/step - loss: 1.2867
#
# ----- Generating text after Epoch: 18
# ----- diversity: 0.2
# ----- Generating with seed: "mall number of ~normal people who would "
# mall number of ~normal people who would be a fucking point to the shit to the project that i was a serious for the state in the show. i was thinking the first time i might be a shit about the state is a strange that i was thinking of the basement of the real thing. i don't know what the fuck is the state is the program with the static stuff. i think i don't know what the players is a bit but i think i have to be a print the state of the
# ----- diversity: 0.5
# ----- Generating with seed: "mall number of ~normal people who would "
# mall number of ~normal people who would have to see a superist goes to be trying to be the heavy tool stuff. i can try to find that like "we should get the trump for the shit. which is completely fucking super familiar here. she was a weird thing more to start a real search for example. but i have a seem to probably say the house for some guy who can't better the one where they do that. i want to see it with the book and the time is thi
# ----- diversity: 1.0
# ----- Generating with seed: "mall number of ~normal people who would "
# mall number of ~normal people who would kill them or still there. miss lied a yad get so long as there. i peopled fontastrul two. https://www.youtube.com/watch?v=wby2unuixwv. eh.... i mean. i'm down to the way in mass two, compared to bad, he's fucking complaint and you man all tages. half teken commanders they were windoomres. i had that manares. into minishing that i liked to them 2'd don't wrassle. do hone, then bergoth in my stories
# ----- diversity: 1.2
# ----- Generating with seed: "mall number of ~normal people who would "
# mall number of ~normal people who would get bad. haha i kind of played "okay opiny since that's what i'm sure for introduceds: or name. ran oh would've fo_graduated would go to tchion. the pluss excusition bitchessal's d joking, intelved-of-itien potus. .vhm level.... i'll get the 'honle it manner. i liked them. man lugaly for 110k, 2017 mpdonightesblantellike
# state of tocaits?. i feel like it's just to cherry. what if it, size putpos w
# Epoch 20/20
# 1540724/1540724 [==============================] - 342s 222us/step - loss: 1.2827
#
# ----- Generating text after Epoch: 19
# ----- diversity: 0.2
# ----- Generating with seed: "portz. sybll trelawney develops a disord"
# portz. sybll trelawney develops a disorder stuff. i don't know what it was a second to the thing that i have the same thing i should have to call them a bit of the money on the company and the state of the project is the problem in the start of the content that i don't know that they don't care about the state of the time that they want to do the state of the state of the experiment thing is the real thing to do that thing i can get the
# ----- diversity: 0.5
# ----- Generating with seed: "portz. sybll trelawney develops a disord"
# portz. sybll trelawney develops a disorder stuff in the character and the start was overwatch. that i made a lot of things and they did the planet. so i didn't like the part of the promised stuff. i don't know what that goes to get well and are still the same thing and i just take a person to disappear that i got it to be discovered to a controlled part. he's saying i have the thing i just don't really like that they were trying to reme
# ----- diversity: 1.0
# ----- Generating with seed: "portz. sybll trelawney develops a disord"
# portz. sybll trelawney develops a disorder (cllaners action). i don't even know who he's against here and thinks mile is the one time on the zalmaps i didn't seemed better than manic is as the father beer, and racing home and new paints. https://www.youtube.com/watch?v=zgdrqxmfmau. daby, but i closed pathfinder in 20 days. once because haking again blood, you entirel how it can make simeating reminds these doctor worn, because once ther
# ----- diversity: 1.2
# ----- Generating with seed: "portz. sybll trelawney develops a disord"
# portz. sybll trelawney develops a disorder kaill/bandra. year?. at all the humblow it. you guys didn't know them and of banting exast?. #obritary. i'll make a mis thing today at 829!99,!.8 for 6t5 subecantires story now, drarchaorian about noviera in 5ceps. failt for brungs some readis/sthare keeps. it would be worse". that's treased charm in the forogy in week. but there's an active people while on, half my same waying week i white meu

# %%
from keras.models import load_model

model.save('speakerC_lstm400_dropout0.2.h5')

# %%
def generateText(seedText):
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        sentence = seedText[:40]
        print('----- Generating with seed: "' + sentence + '"')

        while sentence[-1] != '.' and sentence[-1] != '?':
            x_pred = np.zeros((1, sequenceLength, len(charactersUsed[personUsed])))
            for t, char in enumerate(sentence[-40:]):
                x_pred[0, t, char_to_n[personUsed][char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = n_to_char[personUsed][next_index]

            sentence += next_char
        print(sentence)

# %%
generateText('it generates the 41st character and keeps moving like that. ')
# Out:
# ----- diversity: 0.2
# ----- Generating with seed: "it generates the 41st character and keep"
# it generates the 41st character and keep this one of the time they can take a second time i would be able to say "oh some shit i want to say "oh we have to say it was the one of the station thing i can be a big thing to see the state of the state of the state was the band thing.
# ----- diversity: 0.5
# ----- Generating with seed: "it generates the 41st character and keep"
# it generates the 41st character and keep it the same characters in the deal of the way they said the other time it was a trump and say it was that long things for the day when you say that i don't know what they seem to be problems i can take this one to start to the same expansions in the core in the politics of your about the start part.
# ----- diversity: 1.0
# ----- Generating with seed: "it generates the 41st character and keep"
# it generates the 41st character and keep the jumped to link me what ains leaders but my main ground like scarty fridays to me.
# ----- diversity: 1.2
# ----- Generating with seed: "it generates the 41st character and keep"
# it generates the 41st character and keep the dreams and 5 years og.
